# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn import svm
df=pd.read_excel("C:/Users/amend/Desktop/prev.xlsx")
df.columns
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
dfnew=df.dropna()
dfnew
# Out:
#     gesture Hand_Id        x0        x1            x2        x3        x4  \
# 0      call    Left  0.225915  0.850636 -8.855690e-07  0.218814  0.687799
# 1      call    Left  0.249501  0.680594 -8.618879e-07  0.276895  0.572528
# 2      call    Left  0.539303  0.459862 -1.812308e-07  0.545515  0.435784
# 3      call   Right  0.694729  0.681875 -3.156140e-07  0.664025  0.644881
# 4      call    Left  0.358552  0.527324 -1.161824e-07  0.365468  0.497295
# ..      ...     ...       ...       ...           ...       ...       ...
# 468    stop    Left  0.462234  0.720296  7.552708e-07  0.572533  0.670668
# 469    stop   Right  0.511845  0.678083  4.225339e-07  0.382124  0.631593
# 470    stop    Left  0.527378  0.565309  5.047900e-07  0.602174  0.541307
# 471    stop    Left  0.563128  1.021038  1.072973e-06  0.715769  0.959509
# 472    stop   Right  0.530479  0.542139  2.677811e-07  0.481049  0.500229
#
#            x5        x6        x7  ...       z11       z12       z13  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

x= dfnew
#x=pd.get_dummies(x['Hand_Id'],drop_first=True)
#label_encoder = LabelEncoder()
#df['Hand_Id'] = label_encoder.fit_transform(df['Hand_Id'])

from sklearn.preprocessing import StandardScaler
#x=x.apply(pd.to_numeric)
y=dfnew['gesture']
trainx, testx,trainy,testy=train_test_split(x,y,train_size=0.75,random_state=42)
sc=StandardScaler()
#trainx=sc.fit_transform(trainx)
#testx=sc.fit_transform(testx)
model=svm.SVC()
#model.fit(trainx,trainy)

# %%
pred=model.predict(testx)
acc=accuracy_score(testy,pred)

# %%
acc
# Out:
# 0.20168067226890757

# %%
from sklearn.model_selection import GridSearchCV
modelF=svm.SVC()
parameters= {'C': [0.1, 1, 10, 100,200],  
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  
    'gamma': [1e-3, 1e-2, 1e-1,'scale', 'auto', 0.001, 0.01,0.1], 
    'degree': [2, 3, 4,5,6] }
GridSearchCV(modelF,parameters,cv=5,scoring='accuracy')
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 200], 'degree': [2, 3, 4, 5, 6],
#                          'gamma': [0.001, 0.01, 0.1, 'scale', 'auto', 0.001,
#                                    0.01, 0.1],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='accuracy')

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=0.95)
trainx=pca.fit_transform(trainx)
testx=pca.fit_transform(testx)
modelF.fit(trainx,trainy)
predf=modelF.predict(testx)
accf=accuracy_score(testy,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16924\966176935.py in ?()
#       1 from sklearn.decomposition import PCA
#       2 pca=PCA(n_components=0.95)
# ----> 3 trainx=pca.fit_transform(trainx)
#       4 testx=pca.fit_transform(testx)
#       5 modelF.fit(trainx,trainy)
#       6 predf=modelF.predict(testx)
#
# c:\Users\amend\anaconda3\envs\gesture\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# c:\Users\amend\anaconda3\envs\gesture\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
# ...

# %%
accf
# Out:
# 0.20168067226890757

# %%
import ydf

#modell=ydf.RandomForestLearner(label='gesture',task=ydf.Task.CLASSIFICATION)
modell=ydf.RandomForestLearner(label='gesture')

# %%
train_data = {"features": trainx}
modell.train(dfnew)
# Out:
# Train model on 473 examples
# Model trained in 0:00:00.751114

# %%
path_tst="C:/Users/amend/Desktop/test_ydf.xlsx"
dft=pd.read_excel(path_tst)
dft.columns
dft.replace(r'^\s*$', np.nan, regex=True, inplace=True)
dftnew=dft.dropna()
eval=modell.evaluate(dftnew)
print(eval)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 6
#       4 dft.replace(r'^\s*$', np.nan, regex=True, inplace=True)
#       5 dftnew=dft.dropna()
# ----> 6 eval=modell.evaluate(dftnew)
#       7 print(eval)
#
# AttributeError: 'RandomForestLearner' object has no attribute 'evaluate'
